# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **weather phenomena** (see below) for the region of **Ann Arbor, Michigan, United States**, or **United States** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **Ann Arbor, Michigan, United States** to Ann Arbor, USA. In that case at least one source file must be about **Ann Arbor, Michigan, United States**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **Ann Arbor, Michigan, United States** and **weather phenomena**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **weather phenomena**?  For this category you might want to consider seasonal changes, natural disasters, or historical trends.
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)

# %%
import pandas as pd
import numpy as np
delhi = pd.read_csv('AirQuality_Delhi-2015.csv')
delhi.head()
delhi['Sampling Date'] = pd.to_datetime(delhi['Sampling Date'])
delhi.set_index("Location of Monitoring Station", inplace=True)
# selecting Local monitoring  station - Nizamuddin
delhi = delhi.loc['Nizamuddin, Delhi']
delhi
#Columns - Date and PPB - SO2 and NO2
delcols  = [1,6,7]
delhi = delhi[delhi.columns[delcols]]
delhi['Region']='Nizamuddin'

delhi = delhi.reset_index()
del delhi['Location of Monitoring Station']
delhi.columns = ['Sampling Date', 'SO2 (PPB)', 'NO2 (PPB)', 'Region']
delhi
# date_index = pd.DatetimeIndex(delhi['Sampling Date'])
# delhi["Year"] = date_index.year
# delhi["Month"] = date_index.month
# delhi["Day"] = date_index.day
# #daily 24 hours mean
# data_mean_delhi = delhi.groupby(["Year", "Month", "Day"])["SO2 (PPM)"].mean()
# data_mean_delhi
delhi = (delhi[['SO2 (PPB)','NO2 (PPB)']].rename(columns={
            'SO2':'SO2 [ppb]',  
            'NO2':'NO2 [ppb]'}).unstack().reset_index(level=0)
            .rename(columns={'level_0': 'Pollutant', 0:'Value'}))
delhi['Region']='Nizamuddin'
delhi
# Out:
#     Pollutant  Value      Region
# 0   SO2 (PPB)    4.0  Nizamuddin
# 1   SO2 (PPB)    4.0  Nizamuddin
# 2   SO2 (PPB)    4.0  Nizamuddin
# 3   SO2 (PPB)    4.0  Nizamuddin
# 4   SO2 (PPB)    4.0  Nizamuddin
# 5   SO2 (PPB)    4.0  Nizamuddin
# 6   SO2 (PPB)    4.0  Nizamuddin
# 7   SO2 (PPB)    4.0  Nizamuddin
# 8   SO2 (PPB)    4.0  Nizamuddin
# 9   SO2 (PPB)    4.0  Nizamuddin
# 10  SO2 (PPB)    4.0  Nizamuddin
# 11  SO2 (PPB)    4.0  Nizamuddin
# 12  SO2 (PPB)    4.0  Nizamuddin
# 13  SO2 (PPB)    4.0  Nizamuddin
# 14  SO2 (PPB)    4.0  Nizamuddin
# 15  SO2 (PPB)    4.0  Nizamuddin
# 16  SO2 (PPB)    4.0  Nizamuddin
# 17  SO2 (PPB)    4.0  Nizamuddin
# 18  SO2 (PPB)    4.0  Nizamuddin
# 19  SO2 (PPB)    4.0  Nizamuddin
# 20  SO2 (PPB)    4.0  Nizamuddin
# 21  SO2 (PPB)    4.0  Nizamuddin
# 22  SO2 (PPB)    4.0  Nizamuddin
# 23  SO2 (PPB)    4.0  Nizamuddin
# 24  SO2 (PPB)    4.0  Nizamuddin
# 25  SO2 (PPB)    4.0  Nizamuddin
# 26  SO2 (PPB)    4.0  Nizamuddin
# ...

# %%
# newyork = pd.read_csv('NY.csv')
# newyork.head()
# newyork['Date Local']=pd.to_datetime(newyork['Date Local'])
# newyork.head()
# newyork.set_index("Local Site Name", inplace=True)
# #local station - North Birmingham
# newyork = newyork.loc["North Birmingham"]
# newyork.head()
# #Columns - Date and PPB - SO2
# nycols = [11, 14 ]
# newyork =newyork[ newyork.columns[nycols]]
# newyork['Region']='North Birmingham'


# newyork = newyork.reset_index()
# del newyork['Local Site Name']
# newyork.columns = ['Sampling Date', 'NO2 (PPM)', 'Region']
# date_index = pd.DatetimeIndex(delhi['Sampling Date'])
# delhi["Year"] = date_index1.year
# delhi["Month"] = date_index1.month
# delhi["Day"] = date_index1.day
# #daily 24 hours mean
# data_mean_newyork= delhi.groupby(["Year", "Month", "Day"])["NO2 (PPM)"].mean()
# data_mean_newyork

punjab = pd.read_csv('AirQuality_Punjab-2015.csv')
punjab.head()
punjab['Sampling Date'] = pd.to_datetime(punjab['Sampling Date'])
punjab.set_index("Location of Monitoring Station", inplace=True)
# selecting Local monitoring station - The Ludhiana Dist. Coop. Milk Producers Union Ltd., Ferozpur Road, Ludhiana.
punjab = punjab.loc['The Ludhiana Dist. Coop. Milk Producers Union Ltd., Ferozpur Road, Ludhiana.']
#Columns - Date and PPB - SO2 and NO2
puncols  = [1,6,7]
punjab = punjab[punjab.columns[puncols]]
punjab['Region']='Ludhiana'

punjab = punjab.reset_index()
del punjab['Location of Monitoring Station']
punjab.columns = ['Sampling Date', 'SO2 (PPB)', 'NO2 (PPB)', 'Region']
punjab
# date_index = pd.DatetimeIndex(delhi['Sampling Date'])
# delhi["Year"] = date_index.year
# delhi["Month"] = date_index.month
# delhi["Day"] = date_index.day
# #daily 24 hours mean
# data_mean_delhi = delhi.groupby(["Year", "Month", "Day"])["SO2 (PPM)"].mean()
# data_mean_delhi
punjab = (punjab[['SO2 (PPB)','NO2 (PPB)']].rename(columns={
            'SO2':'SO2 [ppb]',  
            'NO2':'NO2 [ppb]'}).unstack().reset_index(level=0)
            .rename(columns={'level_0': 'Pollutant', 0:'Value'}))
punjab['Region']='Ludhiana'
punjab
# Out:
#      Pollutant  Value    Region
# 0    SO2 (PPB)    9.0  Ludhiana
# 1    SO2 (PPB)    9.0  Ludhiana
# 2    SO2 (PPB)   11.0  Ludhiana
# 3    SO2 (PPB)   10.0  Ludhiana
# 4    SO2 (PPB)   10.0  Ludhiana
# 5    SO2 (PPB)    NaN  Ludhiana
# 6    SO2 (PPB)   12.0  Ludhiana
# 7    SO2 (PPB)    9.0  Ludhiana
# 8    SO2 (PPB)   10.0  Ludhiana
# 9    SO2 (PPB)    9.0  Ludhiana
# 10   SO2 (PPB)    9.0  Ludhiana
# 11   SO2 (PPB)    9.0  Ludhiana
# 12   SO2 (PPB)   10.0  Ludhiana
# 13   SO2 (PPB)   10.0  Ludhiana
# 14   SO2 (PPB)   10.0  Ludhiana
# 15   SO2 (PPB)   11.0  Ludhiana
# 16   SO2 (PPB)   11.0  Ludhiana
# 17   SO2 (PPB)    7.0  Ludhiana
# 18   SO2 (PPB)   10.0  Ludhiana
# 19   SO2 (PPB)   11.0  Ludhiana
# 20   SO2 (PPB)   10.0  Ludhiana
# 21   SO2 (PPB)   14.0  Ludhiana
# 22   SO2 (PPB)    9.0  Ludhiana
# 23   SO2 (PPB)   11.0  Ludhiana
# 24   SO2 (PPB)    9.0  Ludhiana
# 25   SO2 (PPB)   10.0  Ludhiana
# 26   SO2 (PPB)    9.0  Ludhiana
# 27   SO2 (PPB)    8.0  Ludhiana
# ...

# %%
# #merging in order to get dates of Birmingham that match dates of Nizamuddin
# new_newyork = pd.merge(left=delhi, left_on='Sampling Date',
#          right=newyork, right_on='Date Local')
# new_newyork
# # new_newyork.columns = ['Sampling Date', 'NO2 (PPM) for Delhi', 'Date Local', 'NO2 (PPM) for North Birmingham']
# new_newyork.drop(new_newyork.columns[[1,2,3]], axis=1, inplace=True)
# new_newyork.columns = ['Sampling Date', 'NO2 (PPM)']
# new_newyork['Region']='North Birmingham'
# new_newyork

# %%
import matplotlib.pyplot as plt
# merging = pd.merge(left=delhi, left_on='Sampling Date',
#          right=new_newyork, right_on='Sampling Date')
# merging
air_qual = pd.concat([delhi, punjab], axis=0)
# air_qual
plt.figure(figsize=(12,6))
sns.violinplot(x="Pollutant", y="Value", hue="Region", data=air_qual, split=True, inner='quartile');
plt.xlabel('Pollutant', fontsize=25, labelpad=20);
plt.ylabel('Pollutant Emissions', fontsize=25);
plt.rc('xtick', labelsize=15);
plt.rc('ytick', labelsize=15);
plt.legend(loc='upper right', fontsize=15);
ttl = plt.title('Comparison of pollutant emissions in 2015 between Delhi (Nizamuddin) and Punjab(Ludhiana)', fontsize=20)
plt.show()
# Out:
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
